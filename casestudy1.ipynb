# %% [markdown]
# <a href="https://colab.research.google.com/github/suraj-safi1/Appointmentletter/blob/main/casestudy1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
pip install pandas
# Out:
# ...
#   Created wheel for panda: filename=panda-0.3.1-py3-none-any.whl size=7255 sha256=3be7be078a02c098afb03ee728eb1fbf19478c57b7a2b85f8e708cf8e037025b
#   Stored in directory: /root/.cache/pip/wheels/e6/3d/81/a3665ce657d35359ca337b1db2975dbe5cd281a88b8982f6b6
# Successfully built panda
# ...

# %%
import pandas as pd

# %%
dict=  { 'name':['suraj','ammy','ram','rakesh'],
      'marks':[10,24,56,78]
      }
df=pd.DataFrame(dict)
print(df)
# Out:
#      name  marks
# 0   suraj     10
# 1    ammy     24
# 2     ram     56
# 3  rakesh     78

# %%
tips=pd.read_excel("/content/MARKS SLIP.xlsx")

# %%
tips
# Out:
#    K.V NO.1 BANBASA CANTT           Unnamed: 1    Unnamed: 2 Unnamed: 3
# 0              MARKS SLIP                  NaN           NaN        NaN
# 1                    EXAM      PREODIC TEST -2           NaN        NaN
# 2                   CLASS                    7           SEC          B
# 3                 SUBJECT                MATHS           NaN        NaN
# 4               MAX MARKS                  NaN            40        NaN
# 5         NO. OF ANS BOOK                  NaN            39        NaN
# 6                 ROLL NO         STUDENT NAME  MARKS OBTAIN        NaN
# 7                       1        AKANSHA KOHLI            25        NaN
# 8                       2           ALISHA PAL            22        NaN
# 9                       3         ISAB KHATOON            36        NaN
# 10                      4          JYOTI BOHRA            35        NaN
# 11                      5           KM. PREETI            30        NaN
# ...

# %%
tips.head()
# Out:
#   K.V NO.1 BANBASA CANTT       Unnamed: 1 Unnamed: 2 Unnamed: 3
# 0             MARKS SLIP              NaN        NaN        NaN
# 1                   EXAM  PREODIC TEST -2        NaN        NaN
# 2                  CLASS                7        SEC          B
# 3                SUBJECT            MATHS        NaN        NaN
# 4              MAX MARKS              NaN         40        NaN

# %%
tips.head(20)
# Out:
#    K.V NO.1 BANBASA CANTT       Unnamed: 1    Unnamed: 2 Unnamed: 3
# 0              MARKS SLIP              NaN           NaN        NaN
# 1                    EXAM  PREODIC TEST -2           NaN        NaN
# 2                   CLASS                7           SEC          B
# 3                 SUBJECT            MATHS           NaN        NaN
# 4               MAX MARKS              NaN            40        NaN
# 5         NO. OF ANS BOOK              NaN            39        NaN
# 6                 ROLL NO     STUDENT NAME  MARKS OBTAIN        NaN
# 7                       1    AKANSHA KOHLI            25        NaN
# 8                       2       ALISHA PAL            22        NaN
# 9                       3     ISAB KHATOON            36        NaN
# 10                      4      JYOTI BOHRA            35        NaN
# 11                      5       KM. PREETI            30        NaN
# 12                      6             MAHI            28        NaN
# ...

# %%
Std=pd.DataFrame(tips)

# %%
Std.shape
# Out:
# (56, 4)

# %%
Std.columns
# Out:
# Index(['K.V NO.1 BANBASA CANTT', 'Unnamed: 1', 'Unnamed: 2', 'Unnamed: 3'], dtype='object')

# %%
Std.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 56 entries, 0 to 55
# Data columns (total 4 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   K.V NO.1 BANBASA CANTT  46 non-null     object
#  1   Unnamed: 1              50 non-null     object
#  2   Unnamed: 2              47 non-null     object
#  3   Unnamed: 3              1 non-null      object
# dtypes: object(4)
# memory usage: 1.9+ KB

# %%
Std.min()
# Out:
# Series([], dtype: float64)

# %%
Std.max()
# Out:
# Series([], dtype: float64)

# %%
Std.columns
# Out:
# Index(['K.V NO.1 BANBASA CANTT', 'Unnamed: 1', 'Unnamed: 2', 'Unnamed: 3'], dtype='object')

# %%
Std['Unnamed: 1']
# Out:
# 0                     NaN
# 1         PREODIC TEST -2
# 2                       7
# 3                   MATHS
# 4                     NaN
# 5                     NaN
# 6            STUDENT NAME
# 7           AKANSHA KOHLI
# 8              ALISHA PAL
# 9            ISAB KHATOON
# 10            JYOTI BOHRA
# 11             KM. PREETI
# 12                   MAHI
# 13                  MEGHA
# 14         VANSHIKA CHAND
# 15         BHAWANA SHARMA
# 16              JYOTI RAI
# 17                 GUNJAN
# 18           VIDHYA CHAND
# 19                  KOMAL
# 20     PRAGATI CHITRANSHI
# 21            AADITYA RAJ
# 22     AADITYA VISHVKARMA
# 23            ANKIT BHATT
# 24                  ARYAN
# 25       HEMANT PRAJAPATI
# 26       HIMANSHU CHANDRA
# 27           JEEWAN JOSHI
# 28         KUNAL BHANDARI
# 29           MAYANK JOSHI
# 30     NIKHIL KUMAR SINGH
# 31           NITIN PRASAD
# 32           PIYUSH CHAND
# 33        PRIYANSHU KOHLI
# 34         RAJAT DAUSAUNI
# ...

# %%
Std['Unnamed: 1'].value_counts()
# Out:
# AADITYA RAJ            1
# PASS %                 1
# MAYANK JOSHI           1
# MEGHA                  1
# BHAWANA SHARMA         1
# MAHI                   1
# TOTAL STRENGTH         1
# SIG. CHECKER           1
# ARYAN                  1
# JATIN KUMAR            1
# ISAB KHATOON           1
# NO. OF STUDENT APP.    1
# JYOTI RAI              1
# JAFAR HUSSAIN          1
# TOHID HUSSAIN          1
# KM. PREETI             1
# SANDEEP KUMAR          1
# GUNJAN                 1
# OVI PANT               1
# HEMANT PRAJAPATI       1
# KAMESH BHATT           1
# 7                      1
# ALISHA PAL             1
# NIKHIL KUMAR SINGH     1
# PIYUSH CHAND           1
# VIDHYA CHAND           1
# AADITYA VISHVKARMA     1
# NITIN MEHTA            1
# SAMEER BHANDARI        1
# PRAGATI CHITRANSHI     1
# JYOTI BOHRA            1
# MATHS                  1
# RAJAT DAUSAUNI         1
# JEEWAN JOSHI           1
# SIG. EXAMINER          1
# VANSHIKA CHAND         1
# ROHAN CHAND            1
# ...
